# %% [markdown]
# ###  First Exercise
#
# In this exercise, your task is to do the following two things:
#
# 1. **Draw** the following circuit using **SchemDraw**.
# 2. **Analyze** the circuit using **PySpice** and determine the transient currents of **d-e** and **c-e** and their voltages.
#
# > ![Circuit Diagram](Figure1.png)
#
# Use the provided videos and files on the VU site as a reference. Fill in the necessary parts of the code where marked:
#
# ```python
# # complete here...
# ```
#
# Ensure your analysis includes the correct placement of voltage sources and resistors, and that all node connections are properly defined in the simulation.
#
# ---

# %%
# Fig.1

import schemdraw
from schemdraw import elements as elm

with schemdraw.Drawing() as d:

# complete here

# %%
from PySpice.Spice.Netlist import Circuit
from PySpice.Unit import *

circuit = Circuit('Circuit One')

# complete here

simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis = simulator.operating_point()

# complete V_de (voltage difference d & e) and V_ce (voltage difference c & e)
V_de = ...
print(V_de)
V_ce = ...
print(V_ce)

print("----------Voltage of each nodes----------")

for node in analysis.nodes.values(): 
    print('Node {}: {:4.1f} V'.format(str(node), float(node)))
    
print("----------Current of each branches----------")

for branch in analysis.branches.values(): 
    print('Node {}: {:5.2f} A'.format(str(branch), float(branch)))

# %% [markdown]
# ###  Second Exercise
#
# In this exercise, your task is to do the following two things:
#
# 1. **Draw** the following circuit using **SchemDraw**.
# 2. **Analyze** the circuit using **PySpice** and determine $ I_1 $,$ I_2 $ and $ V_x $.
#
# > ![Circuit Diagram](Figure2.png)
#
# You **do not** need to draw the current arrows — just the components and connections.
#
# Use the provided videos and files on the VU site as a reference. Fill in the necessary parts of the code where marked:
#
# ```python
# # complete here...
# ```
#
# Ensure your analysis includes the correct placement of voltage sources and resistors, and that all node connections are properly defined in the simulation.
#
# ---

# %%
# Fig.2

import schemdraw
from schemdraw import elements as elm

with schemdraw.Drawing() as d:

# complete here

# %%
from PySpice.Spice.Netlist import Circuit
from PySpice.Unit import *

circuit = Circuit('Circuit TWo')

# complete here

simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis = simulator.operating_point()

# complete here
V_x = ...
print(V_x)

print("----------Voltage of each nodes----------")

for node in analysis.nodes.values(): 
    print('Node {}: {:4.1f} V'.format(str(node), float(node)))
    
print("----------Current of each branches----------")

for branch in analysis.branches.values(): 
    print('Node {}: {:5.2f} A'.format(str(branch), float(branch)))

# %% [markdown]
# ###  Third Exercise
#
# In this exercise, your task is twofold:
#
# 1. **Draw** the following circuit using **SchemDraw**.
# 2. **Analyze** the circuit using **PySpice**.
#
# <p align="center">
#   <img src="Figure_1.png" width="50%">
# </p>
#
# Use the provided videos and files on the VU site as a reference. Fill in the necessary parts of the code where marked:
#
# ```python
# # complete here...
# ```
#
# Ensure your analysis includes the correct placement of voltage sources and resistors, and that all node connections are properly defined in the simulation.
#
# ---

# %%
import schemdraw
import schemdraw.elements as elm

with schemdraw.Drawing() as d:
    # complete here
    pass

# %%
from PySpice.Spice.Netlist import Circuit
from PySpice.Unit import *

circuit = Circuit('Circuit Three')

# complete here

simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis = simulator.operating_point()

simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis = simulator.operating_point()

print("----------Voltage of each nodes----------")

for node in analysis.nodes.values(): 
    print('Node {}: {:4.6f} V'.format(str(node), float(node)))
    
print("----------Current of each branches----------")

for branch in analysis.branches.values(): 
    print('Node {}: {:5.6f} A'.format(str(branch), float(branch)))

# %% [markdown]
# ###  Fourth Exercise
#
# In this exercise, your task is twofold:
#
# 1. **Draw** the following circuit using **SchemDraw**.
# 2. **Analyze** the circuit using **PySpice** and calculate $ V_o $.
#
# <p align="center">
#   <img src="Figure4.png" width="50%">
# </p>
#
# Use the provided videos and files on the VU site as a reference. Fill in the necessary parts of the code where marked:
#
# ```python
# # complete here...
# ```
#
# Ensure your analysis includes the correct placement of voltage sources and resistors, and that all node connections are properly defined in the simulation.
#
# ---

# %%
import schemdraw
import schemdraw.elements as elm

with schemdraw.Drawing() as d:
    # complete here
    pass

# %%
from PySpice.Spice.Netlist import Circuit
from PySpice.Unit import *

circuit = Circuit('Circuit four')

# complete here

simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis = simulator.operating_point()

simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis = simulator.operating_point()

print("----------Voltage of each nodes----------")

for node in analysis.nodes.values(): 
    print('Node {}: {:4.6f} V'.format(str(node), float(node)))
    
print("----------Current of each branches----------")

for branch in analysis.branches.values(): 
    print('Node {}: {:5.6f} A'.format(str(branch), float(branch)))
